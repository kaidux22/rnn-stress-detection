# %% [markdown]
# #Диаграммы Ящик с Усами
# ##Задачи бинарной классификации
# ###Внешнее окно длиной 15 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt



# Извлеченные значения F1-score для каждого timestep
f1_scores = {
    1: [0.971677559912854, 0.8508771929824561, 0.8925233644859814, 0.868421052631579,  0.8519362186788155, 0.9396551724137931, 0.8486238532110092, 0.9196428571428571, 0.9608695652173913, 0.9593147751605996],
    2: [],
    3: [],
    4: [0.8623024830699775, 0.9307359307359307, 0.851063829787234, 0.7433155080213903, 0.8552036199095022, 0.8095238095238095, 0.9230769230769231, 0.8564814814814815, 0.9336188436830836, 0.8913525498891353],
    5: [0.8785871964679912, 0.8847058823529412, 0.8838268792710706, 0.8755555555555555, 0.8597701149425288, 0.8822170900692841, 0.9383259911894273, 0.8663594470046083, 0.8984198645598194, 0.9028077753779697],
    6: [0.9224137931034483, 0.9406593406593406, 0.8367816091954023, 0.8597701149425288, 0.8765957446808511, 0.8744588744588745, 0.8558758314855875, 0.7970660146699267, 0.9082774049217002, 0.8],
    7: [0.9107142857142857, 0.9139072847682119, 0.8981481481481481, 0.8380952380952381, 0.905829596412556, 0.8654708520179372, 0.8826086956521739, 0.8741418764302059, 0.8951965065502183, 0.8393285371702638],
    8: [0.8519362186788155, 0.7393617021276596, 0.9070294784580499, 0.8133971291866029, 0.9241071428571429, 0.8564705882352941, 0.26119402985074625, 0.8691588785046729, 0.8232662192393736, 0.9042316258351893]
}

# Цвета для боксов
color_divisible = '#4CAF50'  # Зеленый (делится нацело)
color_not_divisible = '#FFA500'  # Оранжевый (не делится)
window_size = 15

# Подготовка данных для boxplot
timesteps = sorted(f1_scores.keys())
data = [f1_scores[ts] for ts in timesteps]

# Параметры стиля
boxprops = dict(linestyle='-', linewidth=1, color='black', facecolor='orange')
medianprops = dict(linestyle='-', linewidth=2, color='black')
whiskerprops = dict(linestyle='-', linewidth=1, color='black')
capprops = dict(linestyle='-', linewidth=1, color='black')
flierprops = dict(marker='o', markersize=8, markerfacecolor='grey')

# Создание boxplot
plt.figure(figsize=(12, 6))
box = plt.boxplot(data,
                 tick_labels=timesteps,
                 boxprops=boxprops,
                 medianprops=medianprops,
                 whiskerprops=whiskerprops,
                 capprops=capprops,
                 flierprops=flierprops,
                 patch_artist=True)  # Исправлено на tick_labels


plt.title('Метрика качества F1 (длина внутреннего окна 15 секунд)', fontsize=14, pad=20)
plt.xlabel('Количество наблюдений временных рядов датасета (t)', fontsize=12, labelpad=10)
plt.ylabel('Метрика качества F1', fontsize=12, labelpad=10)
plt.ylim(0.6, 1)
plt.grid(True, linestyle='--', alpha=0.7, linewidth=0.5)

plt.tight_layout()
# Увеличиваем толщину осей
for axis in ['top','bottom','left','right']:
    plt.gca().spines[axis].set_linewidth(1.5)

plt.show()

# %% [markdown]
# ###Внешнее окно длиной 30 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt



# Извлеченные значения F1-score для каждого timestep
f1_scores = {
    1: [0.971677559912854, 0.8508771929824561, 0.8925233644859814, 0.868421052631579,  0.8519362186788155, 0.9396551724137931, 0.8486238532110092, 0.9196428571428571, 0.9608695652173913, 0.9593147751605996],
    2: [0.9188034188034188, 0.9044289044289044, 0.9336283185840708, 0.8440366972477065, 0.8951965065502183, 0.825, 0.9550321199143469, 0.8344988344988346, 0.9301310043668122, 0.9650655021834061],
    3: [0.8473804100227791, 0.9393939393939394, 0.8308977035490606, 0.8898876404494382, 0.8608695652173913, 0.8610478359908884, 0.8463356973995272, 0.8509615384615384, 0.8423529411764706, 0.90744920993228],
    4: [0.8444444444444444, 0.8354430379746836, 0.9385964912280702, 0.6235294117647059, 0.8546637744034707, 0.8551724137931035, 0.8318965517241379, 0.8153153153153153, 0.8726415094339622, 0.8898876404494382],
    5: [0.8346153846153846, 0.8977777777777778, 0.6217008797653959, 0.8511627906976744, 0.9356223175965666, 0.8177339901477833, 0.9473684210526315, 0.8356807511737089, 0.8414096916299559, 0.8928571428571429],
    6: [0.8314606741573034, 0.8091954022988506, 0.813953488372093, 0.8619854721549637, 0.8054919908466819, 0.9288888888888889, 0.8665105386416861, 0.888402625820569, 0.8978723404255319, 0.6797752808988764],
    7: [0.9509594882729211, 0.8290398126463701, 0.9572649572649573, 0.8108108108108109, 0.9247311827956989, 0.8577981651376146, 0.8374164810690423, 0.6324786324786325, 0.8301886792452831, 0.8729792147806005],
    8: [0.89749430523918, 0.819047619047619, 0.9122807017543859, 0.8519362186788155, 0.8707482993197279, 0.8617511520737328, 0.85, 0.8300220750551877, 0.7786259541984732, 0.8452655889145496]
}

# Цвета для боксов
color_divisible = '#4CAF50'  # Зеленый (делится нацело)
color_not_divisible = '#FFA500'  # Оранжевый (не делится)
window_size = 30

# Подготовка данных для boxplot
timesteps = sorted(f1_scores.keys())
data = [f1_scores[ts] for ts in timesteps]

# Параметры стиля
boxprops = dict(linestyle='-', linewidth=1, color='black', facecolor='orange')
medianprops = dict(linestyle='-', linewidth=2, color='black')
whiskerprops = dict(linestyle='-', linewidth=1, color='black')
capprops = dict(linestyle='-', linewidth=1, color='black')
flierprops = dict(marker='o', markersize=8, markerfacecolor='grey')

# Создание boxplot
plt.figure(figsize=(12, 6))
box = plt.boxplot(data,
                 tick_labels=timesteps,
                 boxprops=boxprops,
                 medianprops=medianprops,
                 whiskerprops=whiskerprops,
                 capprops=capprops,
                 flierprops=flierprops,
                 patch_artist=True)  # Исправлено на tick_labels



plt.title('Метрика качества F1 (длина внутреннего окна 30 секунд)', fontsize=14, pad=20)
plt.xlabel('Количество наблюдений временных рядов датасета (t)', fontsize=12, labelpad=10)
plt.ylabel('Метрика качества F1', fontsize=12, labelpad=10)
plt.ylim(0.6, 1)
plt.grid(True, linestyle='--', alpha=0.7, linewidth=0.5)

plt.tight_layout()
# Увеличиваем толщину осей
for axis in ['top','bottom','left','right']:
    plt.gca().spines[axis].set_linewidth(1.5)

plt.show()

# %% [markdown]
# ###Внешнее окно длиной 45 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt

# Извлеченные значения F1-score для каждого timestep
f1_scores = {
    1: [0.971677559912854, 0.8508771929824561, 0.8925233644859814, 0.868421052631579,  0.8519362186788155, 0.9396551724137931, 0.8486238532110092, 0.9196428571428571, 0.9608695652173913, 0.9593147751605996],
    2: [0.9572649572649573, 0.8538283062645011, 0.84375, 0.8818181818181818, 0.9649122807017544, 0.9139072847682119, 0.8359550561797753, 0.9178082191780822, 0.9324618736383442, 0.82560706401766],
    3: [0.8381374722838137, 0.8421052631578947, 0.8824833702882483, 0.9173553719008265, 0.8413793103448276, 0.8571428571428571, 0.8364485981308412, 0.8251748251748252, 0.9166666666666666, 0.8251121076233184],
    4: [0.9396551724137931, 0.8237986270022883, 0.8486238532110092, 0.7981651376146789, 0.8741418764302059, 0.9333333333333333, 0.8248847926267281, 0.762402088772846, 0.8929384965831435, 0.8721461187214612],
    5: [0.7990867579908676, 0.9036402569593148, 0.9210526315789473, 0.7393617021276596, 0.8143459915611815, 0.8161434977578476, 0.8845315904139434, 0.8869179600886918, 0.6705035971223021],
    6: [0.8735632183908046, 0.9309576837416481, 0.8584269662921349, 0.8028846153846154, 0.8283261802575107, 0.936542669584245, 0.8028503562945368, 0.7868852459016393, 0.8707482993197279, 0.8773584905660378],
    7: [0.8893709327548807, 0.7969924812030075, 0.7930174563591023, 0.8847926267281107, 0.8514412416851441, 0.8275862068965517, 0.8320802005012531, 0.85, 0.8790697674418605, 0.9393939393939394],
    8: [0.8473118279569892, 0.7952380952380952, 0.9070796460176991, 0.8565488565488566, 0.926829268292683, 0.9213973799126638, 0.7306666666666667, 0.9321663019693655, 0.8808988764044944, 0.812807881773399]
}

# Подготовка данных для boxplot
timesteps = sorted(f1_scores.keys())
data = [f1_scores[ts] for ts in timesteps]

# Параметры стиля
boxprops = dict(linestyle='-', linewidth=1, color='black', facecolor='orange')
medianprops = dict(linestyle='-', linewidth=2, color='black')
whiskerprops = dict(linestyle='-', linewidth=1, color='black')
capprops = dict(linestyle='-', linewidth=1, color='black')
flierprops = dict(marker='o', markersize=8, markerfacecolor='grey')

# Создание boxplot
plt.figure(figsize=(12, 6))
box = plt.boxplot(data,
                 tick_labels=timesteps,
                 boxprops=boxprops,
                 medianprops=medianprops,
                 whiskerprops=whiskerprops,
                 capprops=capprops,
                 flierprops=flierprops,
                 patch_artist=True)  # Исправлено на tick_labels
plt.title('Метрика качества F1 (длина внутреннего окна 45 секунд)', fontsize=14, pad=20)
plt.xlabel('Количество наблюдений временных рядов датасета (t)', fontsize=12, labelpad=10)
plt.ylabel('Метрика качества F1', fontsize=12, labelpad=10)
plt.ylim(0.6, 1)
plt.grid(True, linestyle='--', alpha=0.7, linewidth=0.5)

plt.tight_layout()
# Увеличиваем толщину осей
for axis in ['top','bottom','left','right']:
    plt.gca().spines[axis].set_linewidth(1.5)

plt.show()

# %% [markdown]
# ##Задачи многоклассовой классификации (первая модель)
# ###Внешнее окно длиной 15 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt

# Извлеченные значения F1-score для каждого timestep
f1_scores = {
    1: [0.7649630973440509, 0.7600600531746087, 0.7501743010083937, 0.7360511716489582, 0.8281909548612124, 0.7350996426646345, 0.8003439836003463, 0.8005750995091251, 0.7383730720916037, 0.7704225396536364],
    2: [],
    3: [],
    4: [0.6754539860345837, 0.7662920198816976, 0.6980144977764409, 0.7023863655015933, 0.799165334521952, 0.6555799588034087, 0.6711609092473673, 0.7772152259927578, 0.71958467139294, 0.752588824575936],
    5: [0.7353847057178369, 0.785506446119591, 0.7049889094891626, 0.7431357725401169, 0.7342409562930302, 0.7599409122318397, 0.7254244283142942, 0.7377986432965452, 0.6551428438041454, 0.7810032000323966, 0.7406112075954969, 0.7791266622097089, 0.7207914095474535, 0.7119386429654613, 0.757187598262533, 0.7244347826814032, 0.7452541509079839, 0.7854666529196181, 0.7490649219273012, 0.6424795416480971],
    6: [0.7191736889787155, 0.7688941424055907, 0.7310347045656698, 0.7118480089329804, 0.7392675817760808, 0.7579568010754645, 0.6554610920628172, 0.6375030008053908, 0.7292895902164456, 0.7415036279201115],
    7: [0.6096253790549336, 0.656592332940466, 0.727506130667853, 0.7230277290143491, 0.7433516479348848, 0.7231156653796976, 0.7234386955249105, 0.689613014976119, 0.6992838071274641, 0.703760113948067],
    8: [0.7277195562292134, 0.7346660662557603, 0.7282836794359562, 0.7418776157141541, 0.7924235773319036, 0.7006763150894552, 0.6373093713209282, 0.6899581589894778, 0.7040641727966499, 0.7357680605896353]
}

# Подготовка данных для boxplot
timesteps = sorted(f1_scores.keys())
data = [f1_scores[ts] for ts in timesteps]

# Параметры стиля
boxprops = dict(linestyle='-', linewidth=1, color='black', facecolor='orange')
medianprops = dict(linestyle='-', linewidth=2, color='black')
whiskerprops = dict(linestyle='-', linewidth=1, color='black')
capprops = dict(linestyle='-', linewidth=1, color='black')
flierprops = dict(marker='o', markersize=8, markerfacecolor='grey')

# Создание boxplot
plt.figure(figsize=(12, 6))
box = plt.boxplot(data,
                 tick_labels=timesteps,
                 boxprops=boxprops,
                 medianprops=medianprops,
                 whiskerprops=whiskerprops,
                 capprops=capprops,
                 flierprops=flierprops,
                 patch_artist=True)  # Исправлено на tick_labels
plt.title('Метрика качества F1 (длина внутреннего окна 15 секунд)', fontsize=14, pad=20)
plt.xlabel('Количество наблюдений временных рядов датасета (t)', fontsize=12, labelpad=10)
plt.ylabel('Метрика качества F1', fontsize=12, labelpad=10)
plt.ylim(0.6, 0.9)
plt.grid(True, linestyle='--', alpha=0.7, linewidth=0.5)

plt.tight_layout()
# Увеличиваем толщину осей
for axis in ['top','bottom','left','right']:
    plt.gca().spines[axis].set_linewidth(1.5)

plt.show()

# %% [markdown]
# ###Внешнее окно длиной 30 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt

# Извлеченные значения F1-score для каждого timestep
f1_scores = {
    1: [0.7649630973440509, 0.7600600531746087, 0.7501743010083937, 0.7360511716489582, 0.8281909548612124, 0.7350996426646345, 0.8003439836003463, 0.8005750995091251, 0.7383730720916037, 0.7704225396536364],
    2: [0.743941274844987, 0.740140412433137, 0.6959010118114961, 0.7052711802494667, 0.7443078741935628, 0.6794144251404286, 0.7009857155243422, 0.7466460270333982, 0.7490050399250213, 0.755920591596044],
    3: [0.7311703730701581, 0.7779557670156223, 0.7770358819201199, 0.7011211943212908, 0.7461340555733921, 0.715563127551018, 0.7267600323400126, 0.7352002664602748, 0.7187166387190241, 0.7374690771144767],
    4: [0.7351849916153602, 0.7234290333944172, 0.789475270251338, 0.7090750628338761, 0.7599722962224524, 0.7112088209887131, 0.7692368532357974, 0.7586400904527231, 0.7124712495129374, 0.7403016938769739],
    5: [0.6918836384804935, 0.6296911130905787, 0.7474496869155609, 0.7378828721090891, 0.7914468281956095, 0.6544857151212216, 0.7147698126967649, 0.7144284201760925, 0.7132244039451298, 0.7208008609586168],
    6: [0.7051895805893313, 0.7082981317873428, 0.7576518375123152, 0.690762764687911, 0.7159534521803086, 0.7374349246371044, 0.7811307695290461, 0.7603260072530286, 0.653985376375702, 0.7767472316531246],
    7: [0.7357072168142978, 0.7540809954318272, 0.7284336290853537, 0.6693021911371858, 0.7833418344107761, 0.6669246643698048, 0.6537211881095951, 0.7393301629449658, 0.6933273741626099, 0.716423688698901],
    8: [0.7784682419468295, 0.7264168277016353, 0.7246451602447899, 0.7265375348241849, 0.7020513635785763, 0.6779320698536409, 0.6618610667442724, 0.6964941384720987, 0.7448399519642064, 0.760418668787378]
}

# Подготовка данных для boxplot
timesteps = sorted(f1_scores.keys())
data = [f1_scores[ts] for ts in timesteps]

# Параметры стиля
boxprops = dict(linestyle='-', linewidth=1, color='black', facecolor='orange')
medianprops = dict(linestyle='-', linewidth=2, color='black')
whiskerprops = dict(linestyle='-', linewidth=1, color='black')
capprops = dict(linestyle='-', linewidth=1, color='black')
flierprops = dict(marker='o', markersize=8, markerfacecolor='grey')

# Создание boxplot
plt.figure(figsize=(12, 6))
box = plt.boxplot(data,
                 tick_labels=timesteps,
                 boxprops=boxprops,
                 medianprops=medianprops,
                 whiskerprops=whiskerprops,
                 capprops=capprops,
                 flierprops=flierprops,
                 patch_artist=True)  # Исправлено на tick_labels
plt.title('Метрика качества F1 (длина внутреннего окна 30 секунд)', fontsize=14, pad=20)
plt.xlabel('Количество наблюдений временных рядов датасета (t)', fontsize=12, labelpad=10)
plt.ylabel('Метрика качества F1', fontsize=12, labelpad=10)
plt.ylim(0.6, 0.9)
plt.grid(True, linestyle='--', alpha=0.7, linewidth=0.5)

plt.tight_layout()
# Увеличиваем толщину осей
for axis in ['top','bottom','left','right']:
    plt.gca().spines[axis].set_linewidth(1.5)

plt.show()

# %% [markdown]
# ###Внешнее окно длиной 45 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt

# Извлеченные значения F1-score для каждого timestep
f1_scores = {
    1: [0.7649630973440509, 0.7600600531746087, 0.7501743010083937, 0.7360511716489582, 0.8281909548612124, 0.7350996426646345, 0.8003439836003463, 0.8005750995091251, 0.7383730720916037, 0.7704225396536364],
    2: [0.7086602110195764, 0.7387186693638506, 0.7361992115587621, 0.7226670162103043, 0.7507208634400334, 0.7492714221424712, 0.6942285033246214, 0.7139629655035311, 0.7544735885423789, 0.7729799272829677],
    3: [0.7620011373705267, 0.7093289901456885, 0.7187088433507351, 0.744633365413728, 0.7946532120920372, 0.7421305217472506, 0.7480192208551821, 0.7479344358767327, 0.7563918864924374, 0.7912811752432621],
    4: [0.6842640909972585, 0.7052948659739393, 0.7626417397189393, 0.7595073364860294, 0.7171523930433582, 0.7379810425423229, 0.6600002094580286, 0.737582486139538, 0.7461578916390416, 0.7750296768696272],
    5: [0.723284223435298, 0.6996380947038372, 0.7349668703417676, 0.7722853441256476, 0.7766332053225261, 0.7708606887854553, 0.7428091650909195, 0.7553738651093062, 0.7314041103927276, 0.7623727564121744],
    6: [0.6609603677321877, 0.7164103727868291, 0.7317427119634812, 0.7358412219241678, 0.775427112582071, 0.7472801194051681, 0.7624618497913851, 0.6909040086010073, 0.7400094128609526, 0.7049398300092569],
    7: [0.7814443206701625, 0.7278210656966733, 0.7065538929611381, 0.7228713399049156, 0.7243281903944895, 0.6499306958489726, 0.7494581019966662, 0.6738220971649953, 0.7850022768925076, 0.763926227759545],
    8: [0.6532354326409071, 0.6493515792135278, 0.7231934392392728, 0.7350329313346059, 0.6895751162646793, 0.7067347651294597, 0.6378075208617396, 0.7441243697756906, 0.692409326540438, 0.7635119876157246]
}

# Подготовка данных для boxplot
timesteps = sorted(f1_scores.keys())
data = [f1_scores[ts] for ts in timesteps]

# Параметры стиля
boxprops = dict(linestyle='-', linewidth=1, color='black', facecolor='orange')
medianprops = dict(linestyle='-', linewidth=2, color='black')
whiskerprops = dict(linestyle='-', linewidth=1, color='black')
capprops = dict(linestyle='-', linewidth=1, color='black')
flierprops = dict(marker='o', markersize=8, markerfacecolor='grey')

# Создание boxplot
plt.figure(figsize=(12, 6))
box = plt.boxplot(data,
                 tick_labels=timesteps,
                 boxprops=boxprops,
                 medianprops=medianprops,
                 whiskerprops=whiskerprops,
                 capprops=capprops,
                 flierprops=flierprops,
                 patch_artist=True)  # Исправлено на tick_labels
plt.title('Метрика качества F1 (длина внутреннего окна 45 секунд)', fontsize=14, pad=20)
plt.xlabel('Количество наблюдений временных рядов датасета (t)', fontsize=12, labelpad=10)
plt.ylabel('Метрика качества F1', fontsize=12, labelpad=10)
plt.ylim(0.6, 0.9)
plt.grid(True, linestyle='--', alpha=0.7, linewidth=0.5)

plt.tight_layout()
# Увеличиваем толщину осей
for axis in ['top','bottom','left','right']:
    plt.gca().spines[axis].set_linewidth(1.5)

plt.show()

# %% [markdown]
# ##Задачи многоклассовой классификации (вторая модель)
# ###Внешнее окно длиной 15 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt



# Извлеченные значения F1-score для каждого timestep
f1_scores = {
    1: [0.5738743854209447, 0.5506296253980679, 0.5757179312871535, 0.6026051803215688, 0.5797761153679211, 0.5357170943864916, 0.6043878066413358, 0.5626259332055418, 0.5814116959265926, 0.5940429525580763],
    2: [],
    3: [],
    4: [0.6042886064317392, 0.6164671713148537, 0.5486836129902579, 0.5954255498226344, 0.5593522305023664, 0.4366416968438011, 0.5969468642286346, 0.6334687672690894, 0.607897929715052, 0.5903037959895091],
    5: [0.604203134594337, 0.6023113006911013, 0.5248357363257906, 0.5994827134980629, 0.4398157762399692, 0.5749840786234253, 0.6124445912436829, 0.6334631053572702, 0.45405721659193, 0.4718776705587251],
    6: [0.32930487104127926, 0.6119068747110659, 0.6259511298125867, 0.5698753366394802, 0.5990512479447703, 0.6300258233660425, 0.6292753225841135, 0.4864152987695561, 0.6000422774001258, 0.6308000301675477],
    7: [0.4339846345653912, 0.5647217889460768, 0.5966791915731628, 0.5341463799795038, 0.46944508168727134, 0.6108863996214782, 0.5695738187357633, 0.603452369902586, 0.6105438810071585, 0.4761072832759783],
    8: [0.610883262285714, 0.5447746821466515, 0.4720984255001655, 0.2931409617310846, 0.4838739620705561, 0.45991329046047896, 0.46739349582280776, 0.31859479252519435, 0.4471314927323511, 0.465514932582111]
}

# Цвета для боксов
color_divisible = '#4CAF50'  # Зеленый (делится нацело)
color_not_divisible = '#FFA500'  # Оранжевый (не делится)
window_size = 15

# Подготовка данных для boxplot
timesteps = sorted(f1_scores.keys())
data = [f1_scores[ts] for ts in timesteps]

# Параметры стиля
boxprops = dict(linestyle='-', linewidth=1, color='black', facecolor='orange')
medianprops = dict(linestyle='-', linewidth=2, color='black')
whiskerprops = dict(linestyle='-', linewidth=1, color='black')
capprops = dict(linestyle='-', linewidth=1, color='black')
flierprops = dict(marker='o', markersize=8, markerfacecolor='grey')

# Создание boxplot
plt.figure(figsize=(12, 6))
box = plt.boxplot(data,
                 tick_labels=timesteps,
                 boxprops=boxprops,
                 medianprops=medianprops,
                 whiskerprops=whiskerprops,
                 capprops=capprops,
                 flierprops=flierprops,
                 patch_artist=True)


plt.title('Метрика качества F1 (длина внутреннего окна 15 секунд)', fontsize=14, pad=20)
plt.xlabel('Количество наблюдений временных рядов датасета (t)', fontsize=12, labelpad=10)
plt.ylabel('Метрика качества F1', fontsize=12, labelpad=10)
plt.ylim(0.33, 0.66)
plt.grid(True, linestyle='--', alpha=0.7, linewidth=0.5)

plt.tight_layout()
# Увеличиваем толщину осей
for axis in ['top','bottom','left','right']:
    plt.gca().spines[axis].set_linewidth(1.5)

plt.show()

# %% [markdown]
# ###Внешнее окно длиной 30 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt



# Извлеченные значения F1-score для каждого timestep
f1_scores = {
    1: [0.5738743854209447, 0.5506296253980679, 0.5757179312871535, 0.6026051803215688, 0.5797761153679211, 0.5357170943864916, 0.6043878066413358, 0.5626259332055418, 0.5814116959265926, 0.5940429525580763],
    2: [0.4576043411016842, 0.6111063614014438, 0.6188237704343642, 0.4984449030666873, 0.5277680846878896, 0.5788833122368285, 0.5551915528287745, 0.6177694849675787, 0.5830919333547414, 0.5929981112854146],
    3: [0.5986450385692574, 0.6175402810675801, 0.5618374540837126, 0.5719069122698833, 0.6197414936201231, 0.6107245109315689, 0.5934106464524681, 0.620952803036615, 0.5987672991613773, 0.6073954004392201],
    4: [0.4311468048908089, 0.6333067771421256, 0.6305186767144175, 0.4514918048013762, 0.5921196426404706, 0.4631167620411999, 0.6202211903926259, 0.5704551891365025, 0.588417858036317, 0.6104415820796427],
    5: [0.5886488062012835, 0.6308985280245856, 0.5832424541623156, 0.4858204695592321, 0.46351751611790665, 0.5967024986632828, 0.44702865828864247, 0.6221411091640578, 0.5208984765021064, 0.5655921824622316],
    6: [0.5225856555565818, 0.4129169641550471, 0.5669271162435139, 0.6463016611031632, 0.450534004673325, 0.4459741386184543, 0.48009079141893785, 0.5474920729292335, 0.5716837746261387, 0.63273419392044],
    7: [0.4471449673767469, 0.4690963369912887, 0.6284572360640404, 0.5536682151605189, 0.584408830403719, 0.6439267994433008, 0.4642944625542217, 0.48162297677276233, 0.6300147484638483, 0.4504155094887523],
    8: [0.4307920951760892, 0.4704122692178411, 0.5187323329087596, 0.6355376008512087, 0.45303778263476263, 0.6219165253029907, 0.498940268453366, 0.6209458461223236, 0.44892255750384075, 0.6245607319890423]
}

# Цвета для боксов
color_divisible = '#4CAF50'  # Зеленый (делится нацело)
color_not_divisible = '#FFA500'  # Оранжевый (не делится)
window_size = 15

# Подготовка данных для boxplot
timesteps = sorted(f1_scores.keys())
data = [f1_scores[ts] for ts in timesteps]

# Параметры стиля
boxprops = dict(linestyle='-', linewidth=1, color='black', facecolor='orange')
medianprops = dict(linestyle='-', linewidth=2, color='black')
whiskerprops = dict(linestyle='-', linewidth=1, color='black')
capprops = dict(linestyle='-', linewidth=1, color='black')
flierprops = dict(marker='o', markersize=8, markerfacecolor='grey')

# Создание boxplot
plt.figure(figsize=(12, 6))
box = plt.boxplot(data,
                 tick_labels=timesteps,
                 boxprops=boxprops,
                 medianprops=medianprops,
                 whiskerprops=whiskerprops,
                 capprops=capprops,
                 flierprops=flierprops,
                 patch_artist=True)  # Исправлено на tick_labels


plt.title('Метрика качества F1 (длина внутреннего окна 30 секунд)', fontsize=14, pad=20)
plt.xlabel('Количество наблюдений временных рядов датасета (t)', fontsize=12, labelpad=10)
plt.ylabel('Метрика качества F1', fontsize=12, labelpad=10)
plt.ylim(0.33, 0.66)
plt.grid(True, linestyle='--', alpha=0.7, linewidth=0.5)

plt.tight_layout()
# Увеличиваем толщину осей
for axis in ['top','bottom','left','right']:
    plt.gca().spines[axis].set_linewidth(1.5)

plt.show()

# %% [markdown]
# ###Внешнее окно длиной 45 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt



# Извлеченные значения F1-score для каждого timestep
f1_scores = {
    1: [0.5738743854209447, 0.5506296253980679, 0.5757179312871535, 0.6026051803215688, 0.5797761153679211, 0.5357170943864916, 0.6043878066413358, 0.5626259332055418, 0.5814116959265926, 0.5940429525580763],
    2: [0.6076239359808103, 0.6142354510531358, 0.6094591831851303, 0.5989120726595013, 0.6034411329595224, 0.5788549960100501, 0.5808330273329462, 0.4454552250898486, 0.61090301892183, 0.5828965899690984],
    3: [0.5846063275957571, 0.6060708748330271, 0.4480266825450483, 0.6080329328865298, 0.5801746356741969, 0.6048910717167297, 0.5665364533886592, 0.6042117777173279, 0.5754976028581179, 0.5911468078734329],
    4: [0.5436994979268526, 0.604602864428041, 0.5868394219588697, 0.4578841100254669, 0.4585373282219026, 0.5023092177881338, 0.5614807648266167, 0.5893806810363363, 0.5044837577043177, 0.5177383291619466],
    5: [0.48259749784168227, 0.5998885291834445, 0.6221675878346868, 0.5386602665639416, 0.621938634673113, 0.6060327873419745, 0.6106353296879445, 0.5381124006275176, 0.6128803201564413, 0.6108724627435476],
    6: [0.4442251892842317, 0.6139814091959221, 0.6133290494825356, 0.6074644907529286, 0.4379645200423763, 0.5486130147579666, 0.5959471462361482, 0.5544603525261118, 0.4599136248398372, 0.4526918380641775],
    7: [0.526752435771889, 0.47193579922807305, 0.6106697938926505, 0.4266741968918069, 0.4595703783653448, 0.6121297061816078, 0.46277039403191805, 0.6211048559713596, 0.5859596395008806, 0.5701671655361172],
    8: [0.445891160905311, 0.432540883999168, 0.26743563284921584, 0.6212493605730145, 0.46048563214704874, 0.5329749029471831, 0.6088319902773144, 0.4239184291924789, 0.4591232821492225, 0.4893286667076215]
}

# Цвета для боксов
color_divisible = '#4CAF50'  # Зеленый (делится нацело)
color_not_divisible = '#FFA500'  # Оранжевый (не делится)
window_size = 15

# Подготовка данных для boxplot
timesteps = sorted(f1_scores.keys())
data = [f1_scores[ts] for ts in timesteps]

# Параметры стиля
boxprops = dict(linestyle='-', linewidth=1, color='black', facecolor='orange')
medianprops = dict(linestyle='-', linewidth=2, color='black')
whiskerprops = dict(linestyle='-', linewidth=1, color='black')
capprops = dict(linestyle='-', linewidth=1, color='black')
flierprops = dict(marker='o', markersize=8, markerfacecolor='grey')

# Создание boxplot
plt.figure(figsize=(12, 6))
box = plt.boxplot(data,
                 tick_labels=timesteps,
                 boxprops=boxprops,
                 medianprops=medianprops,
                 whiskerprops=whiskerprops,
                 capprops=capprops,
                 flierprops=flierprops,
                 patch_artist=True)  # Исправлено на tick_labels


plt.title('Метрика качества F1 (длина внутреннего окна 45 секунд)', fontsize=14, pad=20)
plt.xlabel('Количество наблюдений временных рядов датасета (t)', fontsize=12, labelpad=10)
plt.ylabel('Метрика качества F1', fontsize=12, labelpad=10)
plt.ylim(0.33, 0.66)
plt.grid(True, linestyle='--', alpha=0.7, linewidth=0.5)

plt.tight_layout()
# Увеличиваем толщину осей
for axis in ['top','bottom','left','right']:
    plt.gca().spines[axis].set_linewidth(1.5)

plt.show()

# %% [markdown]
# #Графики времени
# ##Графики времени генерации датасетов
# ###Внешнее окно длиной 15 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 4, 5, 6, 7, 8])  # Создаем массив x от 1 до 10
y = np.array([48.54, 170.2, 325.26, 503.82, 708.47, 943.01])  # Массив y из введенных чисел

# Настраиваем график
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', linewidth=2, label='Время генерации датасета')  # Ломаная линия
plt.scatter(x, y, color='red', s=50)

# Добавляем подписи
plt.title('Время генерации датасета (длина внутреннего окна 15)', fontsize=14)
plt.xlabel('Длительность временных рядов датасета (t)', fontsize=12)
plt.ylabel('Время генерации (с)', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Показываем график
plt.show()

# %% [markdown]
# ###Внешнее окно длиной 30 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5, 6, 7, 8])  # Создаем массив x от 1 до 8
y = np.array([48.54, 1018.42302775383, 1128.6092376708984, 1277.0307970046997, 1464.4546966552734, 1690.6057198047638, 1956.4429867267609, 2257.0196857452393])  # Массив y из введенных чисел

# Настраиваем график
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', linewidth=2, label='Время генерации датасета')  # Ломаная линия
plt.scatter(x, y, color='red', s=50)

# Добавляем подписи
plt.title('Время генерации датасета (длина внутреннего окна 30)', fontsize=14)
plt.xlabel('Длительность временных рядов датасета (t)', fontsize=12)
plt.ylabel('Время генерации (с)', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Показываем график
plt.show()

# %% [markdown]
# ###Внешнее окно длиной 45 секунд

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5, 6, 7, 8])  # Создаем массив x от 1 до 8
y = np.array([48.54, 2343.1, 2469.88, 2638.20, 2852.15, 3110.06, 3410.64, 3755.67])  # Массив y из введенных чисел

# Настраиваем график
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', linewidth=2, label='Время генерации датасета')  # Ломаная линия
plt.scatter(x, y, color='red', s=50)

# Добавляем подписи
plt.title('Время генерации датасета (длина внутреннего окна 45)', fontsize=14)
plt.xlabel('Длительность временных рядов датасета (t)', fontsize=12)
plt.ylabel('Время генерации (с)', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Показываем график
plt.show()

# %% [markdown]
# ##Графики времени предсказания
# ###Бинарная классификация

# %%
import numpy as np
import matplotlib.pyplot as plt

# Данные для первой линии (исходные)
x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y1 = np.array([0.0012290477752685547, 0.0012717247009277344, 0.001371145248413086, 0.0013530254364013672, 0.001344442367553711, 0.0013611316680908203, 0.0014171600341796875, 0.0012955665588378906])
y2 = np.array([0.001107931137084961, 0.00099945068359375, 0.001512289047241211, 0.0010857582092285156, 0.0012280941009521484, 0.001070261001586914, 0.0015480518341064453, 0.0011501312255859375])
y3 = np.array([0.004891157150268555, 0.004094362258911133, 0.0044176578521728516, 0.004391908645629883, 0.00439453125, 0.0048542022705078125, 0.0048944950103759766, 0.006275653839111328])

# Настраиваем график
plt.figure(figsize=(10, 6))

plt.plot(x, y1, 'b-', marker='o', markersize=8, linewidth=2, label='Модель бинарной классификации')
plt.plot(x, y2, 'g-', marker='s', markersize=8, linewidth=2, label='Первая модель многоклассовой классификации')
plt.plot(x, y3, 'r-', marker='^', markersize=8, linewidth=2, label='Вторая модель многоклассовой классификации')

# Добавляем подписи
plt.title('Время предсказания моделей', fontsize=14)
plt.xlabel('Длительность временных рядов (t)', fontsize=12)
plt.ylabel('Время предсказания (с)', fontsize=12)
plt.legend(fontsize=12)  # Легенда для различения линий
plt.grid(True, linestyle='--', alpha=0.7)

# Показываем график
plt.show()

# %% [markdown]
# ##Качество обучения (Precision, Recall, F1)
# ###Бинарная классификация

# %%
import numpy as np
import matplotlib.pyplot as plt

# Предположим, у нас есть данные в таком формате:
# metrics_data[dataset][metric] = список значений
metrics_data = {
    '1': {
        'F1': [0.971677559912854, 0.8508771929824561, 0.8925233644859814, 0.868421052631579,  0.8519362186788155, 0.9396551724137931, 0.8486238532110092, 0.9196428571428571, 0.9608695652173913, 0.9593147751605996],
        'Precision': [0.9572649572649573, 0.9867256637168141, 0.8699551569506726, 0.9794871794871794, 0.8878923766816144, 0.9077669902912622, 0.9437229437229437, 0.9113300492610837, 0.958139534883721, 0.973568281938326],
        'Recall': [0.9613733905579399, 0.9570815450643777, 0.8326180257510729, 0.8197424892703863, 0.8497854077253219, 0.8025751072961373, 0.9356223175965666, 0.7939914163090128, 0.8841201716738197, 0.9484978540772532]
    },
    '2': {
        'F1': [0.9188034188034188, 0.9044289044289044, 0.9336283185840708, 0.8440366972477065, 0.8951965065502183, 0.825, 0.9550321199143469, 0.8344988344988346, 0.9301310043668122, 0.9650655021834061],
        'Precision': [0.9148936170212766, 0.9897959183673469, 0.9634703196347032, 0.9064039408866995, 0.9111111111111111, 0.8016194331983806, 0.9529914529914529, 0.9132653061224489, 0.9466666666666667, 0.9822222222222222],
        'Recall': [0.9227467811158798, 0.8326180257510729, 0.9055793991416309, 0.7896995708154506, 0.8798283261802575, 0.8497854077253219, 0.9570815450643777, 0.7682403433476395, 0.9141630901287554, 0.9484978540772532]
    },
    '3': {
        'F1': [0.8473804100227791, 0.9393939393939394, 0.8308977035490606, 0.8898876404494382, 0.8608695652173913, 0.8610478359908884, 0.8463356973995272, 0.8509615384615384, 0.8423529411764706, 0.90744920993228],
        'Precision': [0.9029126213592233, 0.9475982532751092, 0.8089430894308943, 0.9339622641509434, 0.8722466960352423, 0.9174757281553398, 0.9421052631578948, 0.9672131147540983, 0.9322916666666666, 0.9571428571428572],
        'Recall': [0.7982832618025751, 0.9313304721030042, 0.8540772532188842, 0.8497854077253219, 0.8497854077253219, 0.8111587982832618, 0.7682403433476395, 0.759656652360515, 0.7682403433476395, 0.8626609442060086]
    },
    '4': {
        'F1': [0.8444444444444444, 0.8354430379746836, 0.9385964912280702, 0.6235294117647059, 0.8546637744034707, 0.8551724137931035, 0.8318965517241379, 0.8153153153153153, 0.8726415094339622, 0.8898876404494382],
        'Precision': [0.8755760368663594, 0.8215767634854771, 0.9596412556053812, 0.9906542056074766, 0.8640350877192983, 0.9207920792079208, 0.8354978354978355, 0.8578199052132701, 0.9685863874345549, 0.9339622641509434],
        'Recall': [0.8154506437768241, 0.8497854077253219, 0.9184549356223176, 0.45493562231759654, 0.8454935622317596, 0.7982832618025751, 0.8283261802575107, 0.776824034334764, 0.7939914163090128, 0.8497854077253219]
    },
    '5': {
        'F1': [0.8346153846153846, 0.8977777777777778, 0.6217008797653959, 0.8511627906976744, 0.9356223175965666, 0.8177339901477833, 0.9473684210526315, 0.8356807511737089, 0.8414096916299559, 0.8928571428571429],
        'Precision': [0.7560975609756098, 0.9308755760368663, 0.9814814814814815, 0.9289340101522843, 0.9356223175965666, 0.9595375722543352, 0.968609865470852, 0.9222797927461139, 0.8642533936651584, 0.9302325581395349],
        'Recall': [0.9313304721030042, 0.8669527896995708, 0.45493562231759654, 0.7854077253218884, 0.9356223175965666, 0.7124463519313304, 0.927038626609442, 0.7639484978540773, 0.8197424892703863, 0.8583690987124464]
    },
    '6': {
        'F1': [0.8314606741573034, 0.8091954022988506, 0.813953488372093, 0.8619854721549637, 0.8054919908466819, 0.9288888888888889, 0.8665105386416861, 0.888402625820569, 0.8978723404255319, 0.6797752808988764],
        'Precision': [0.8726415094339622, 0.8712871287128713, 0.8883248730964467, 0.9888888888888889, 0.8627450980392157, 0.9631336405529954, 0.9536082474226805, 0.90625, 0.890295358649789, 0.983739837398374],
        'Recall': [0.7939914163090128, 0.7553648068669528, 0.7510729613733905, 0.7639484978540773, 0.7553648068669528, 0.8969957081545065, 0.7939914163090128, 0.871244635193133, 0.9055793991416309, 0.51931330472103]
    },
    '7': {
        'F1': [0.9509594882729211, 0.8290398126463701, 0.9572649572649573, 0.8108108108108109, 0.9247311827956989, 0.8577981651376146, 0.8374164810690423, 0.6324786324786325, 0.8301886792452831, 0.8729792147806005],
        'Precision': [0.9449152542372882, 0.9123711340206185, 0.9531914893617022, 0.8530805687203792, 0.9267241379310345, 0.9211822660098522, 0.8703703703703703, 0.940677966101695, 0.9214659685863874, 0.945],
        'Recall': [0.9570815450643777, 0.759656652360515, 0.9613733905579399, 0.7725321888412017, 0.9227467811158798, 0.8025751072961373, 0.8068669527896996, 0.47639484978540775, 0.7553648068669528, 0.8111587982832618]
    },
    '8': {
        'F1': [0.89749430523918, 0.819047619047619, 0.9122807017543859, 0.8519362186788155, 0.8707482993197279, 0.8617511520737328, 0.85, 0.8300220750551877, 0.7786259541984732, 0.8452655889145496],
        'Precision': [0.9563106796116505, 0.9197860962566845, 0.9327354260089686, 0.9077669902912622, 0.9230769230769231, 0.9303482587064676, 0.9033816425120773, 0.8545454545454545, 0.95625, 0.915],
        'Recall': [0.8454935622317596, 0.7381974248927039, 0.8927038626609443, 0.8025751072961373, 0.8240343347639485, 0.8025751072961373, 0.8025751072961373, 0.8068669527896996, 0.6566523605150214, 0.7854077253218884]
    }
}

# Цвета для разных метрик
metric_colors = {
    'F1': '#FF9800',
    'Precision': '#2196F3',
    'Recall': '#4CAF50'
}

# Параметры стиля
boxprops = dict(linestyle='-', linewidth=1, color='black')
medianprops = dict(linestyle='-', linewidth=2, color='black')
whiskerprops = dict(linestyle='-', linewidth=1, color='black')
capprops = dict(linestyle='-', linewidth=1, color='black')
flierprops = dict(marker='o', markersize=5, markerfacecolor='grey', alpha=0.5)

# Создание фигуры
plt.figure(figsize=(16, 8))

# Позиции для boxplot'ов
n_datasets = len(metrics_data)
n_metrics = 3
positions = []
current_pos = 1

for i in range(n_datasets):
    for j in range(n_metrics):
        positions.append(current_pos + j*0.5)
    current_pos += 2  # Отступ между датасетами

# Построение boxplot'ов
boxes = []
for i, dataset in enumerate(metrics_data):
    for j, metric in enumerate(['F1', 'Precision', 'Recall']):
        pos = positions[i*n_metrics + j]
        box = plt.boxplot(metrics_data[dataset][metric],
                         positions=[pos],
                         widths=0.3,
                         patch_artist=True,
                         boxprops=boxprops,
                         medianprops=medianprops,
                         whiskerprops=whiskerprops,
                         capprops=capprops,
                         flierprops=flierprops)

        # Закрашиваем box'ы
        for patch in box['boxes']:
            patch.set_facecolor(metric_colors[metric])

        boxes.append(box)

# Настройка осей
xticks_pos = [positions[i*n_metrics + 1] for i in range(n_datasets)]
plt.xticks(xticks_pos, metrics_data.keys())


# Легенда
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor=metric_colors['F1'], label='F1'),
                   Patch(facecolor=metric_colors['Precision'], label='Precision'),
                   Patch(facecolor=metric_colors['Recall'], label='Recall')]
plt.legend(handles=legend_elements, loc='upper right')

# Заголовки и подписи
plt.title('Сравнение метрик качества для 8 датасетов', fontsize=14, pad=20)
plt.xlabel('Датасеты', fontsize=12, labelpad=10)
plt.ylabel('Значение метрики', fontsize=12, labelpad=10)
plt.ylim(0.5, 1.05)
plt.grid(True, linestyle='--', alpha=0.5)

# Увеличиваем толщину осей
for axis in ['top','bottom','left','right']:
    plt.gca().spines[axis].set_linewidth(1.5)

plt.tight_layout()
plt.show()
